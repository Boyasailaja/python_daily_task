# %% [markdown]
# # Pandas

# %%
import pandas as pd
dicts = {"Name" : ["Sailaja Sree","Ritvika","Abhijith"],
         "Age" : [23,15,12],
         "City" : ["Adoni","Hyderabad","Hebutam"]
        }
dicts
# Out:
# {'Name': ['Sailaja Sree', 'Ritvika', 'Abhijith'],
#  'Age': [23, 15, 12],
#  'City': ['Adoni', 'Hyderabad', 'Hebutam']}

# %%
df=pd.DataFrame(dicts)
df
# Out:
#            Name  Age       City
# 0  Sailaja Sree   23      Adoni
# 1       Ritvika   15  Hyderabad
# 2      Abhijith   12    Hebutam

# %%
df=pd.read_csv("C:\\Users\\yuvra\\Downloads\\dataset.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
df.sample()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 185   44    1   0       112   290    0        0      153      0      0.0
#
#      slope  ca  thal  target
# 185      2   1     2       0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.isnull()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
df.isna()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
df['target']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
df[["age","sex","cp"]]
# Out:
#      age  sex  cp
# 0     63    1   3
# 1     37    1   2
# 2     41    0   1
# 3     56    1   1
# 4     57    0   0
# ..   ...  ...  ..
# 298   57    0   0
# 299   45    1   3
# 300   68    1   0
# 301   57    1   0
# 302   57    0   1
#
# [303 rows x 3 columns]

# %%
int_columns=df.select_dtypes(include=["int","float"]).columns
int_columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
len(int_columns)
# Out:
# 14

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.drop("exang", axis=1)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  oldpeak  slope  ca  \
# 0     63    1   3       145   233    1        0      150      2.3      0   0
# 1     37    1   2       130   250    0        1      187      3.5      0   0
# 2     41    0   1       130   204    0        0      172      1.4      2   0
# 3     56    1   1       120   236    0        1      178      0.8      2   0
# 4     57    0   0       120   354    0        1      163      0.6      2   0
# ..   ...  ...  ..       ...   ...  ...      ...      ...      ...    ...  ..
# 298   57    0   0       140   241    0        1      123      0.2      1   0
# 299   45    1   3       110   264    0        1      132      1.2      1   0
# 300   68    1   0       144   193    1        1      141      3.4      1   2
# 301   57    1   0       130   131    0        1      115      1.2      1   1
# 302   57    0   1       130   236    0        0      174      0.0      1   1
#
#      thal  target
# 0       1       1
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# Length: 303, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df["target"].value_counts(dropna=True)
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.drop
# Out:
# <bound method DataFrame.drop of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.rename(columns = {"target" : "Result", "sex" : "Gender"}, inplace=True)
df.columns
# Out:
# Index(['age', 'Gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'Result'],
#       dtype='object')

# %%
df=pd.read_csv("C:\\Users\\yuvra\\Downloads\\dataset.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.rename(columns = {"target" : "Result", "sex" : "Gender"}, inplace=True)
df.columns
# Out:
# Index(['age', 'Gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'Result'],
#       dtype='object')

# %%
df.rename(index={0:"First",1:"Second"})
# Out:
#         age  Gender  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# First    63       1   3       145   233    1        0      150      0
# Second   37       1   2       130   250    0        1      187      0
# 2        41       0   1       130   204    0        0      172      0
# 3        56       1   1       120   236    0        1      178      0
# 4        57       0   0       120   354    0        1      163      1
# ...     ...     ...  ..       ...   ...  ...      ...      ...    ...
# 298      57       0   0       140   241    0        1      123      1
# 299      45       1   3       110   264    0        1      132      0
# 300      68       1   0       144   193    1        1      141      0
# 301      57       1   0       130   131    0        1      115      1
# 302      57       0   1       130   236    0        0      174      0
#
#         oldpeak  slope  ca  thal  Result
# First       2.3      0   0     1       1
# Second      3.5      0   0     2       1
# ...

# %%
# List Comprehension : Using this method we can capitalize the starting letters of columns
df.columns=[Col.title() for Col in df.columns]
df.columns
# Out:
# Index(['Age', 'Gender', 'Cp', 'Trestbps', 'Chol', 'Fbs', 'Restecg', 'Thalach',
#        'Exang', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'Result'],
#       dtype='object')

# %%
df
# Out:
#      Age  Gender  Cp  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  \
# 0     63       1   3       145   233    1        0      150      0      2.3
# 1     37       1   2       130   250    0        1      187      0      3.5
# 2     41       0   1       130   204    0        0      172      0      1.4
# 3     56       1   1       120   236    0        1      178      0      0.8
# 4     57       0   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1      0.2
# 299   45       1   3       110   264    0        1      132      0      1.2
# 300   68       1   0       144   193    1        1      141      0      3.4
# 301   57       1   0       130   131    0        1      115      1      1.2
# 302   57       0   1       130   236    0        0      174      0      0.0
#
#      Slope  Ca  Thal  Result
# ...

# %%
df.add_prefix("Column_")
# Out:
#      Column_Age  Column_Gender  Column_Cp  Column_Trestbps  Column_Chol  \
# 0            63              1          3              145          233
# 1            37              1          2              130          250
# 2            41              0          1              130          204
# 3            56              1          1              120          236
# 4            57              0          0              120          354
# ..          ...            ...        ...              ...          ...
# 298          57              0          0              140          241
# 299          45              1          3              110          264
# 300          68              1          0              144          193
# 301          57              1          0              130          131
# 302          57              0          1              130          236
#
#      Column_Fbs  Column_Restecg  Column_Thalach  Column_Exang  Column_Oldpeak  \
# ...

# %%
df["Oldpeak"] = df["Oldpeak"].astype(int)

# %%
df["Oldpeak"]
# Out:
# 0      2
# 1      3
# 2      1
# 3      0
# 4      0
#       ..
# 298    0
# 299    1
# 300    3
# 301    1
# 302    0
# Name: Oldpeak, Length: 303, dtype: int32

# %%
df
# Out:
#      Age  Gender  Cp  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  \
# 0     63       1   3       145   233    1        0      150      0        2
# 1     37       1   2       130   250    0        1      187      0        3
# 2     41       0   1       130   204    0        0      172      0        1
# 3     56       1   1       120   236    0        1      178      0        0
# 4     57       0   0       120   354    0        1      163      1        0
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1        0
# 299   45       1   3       110   264    0        1      132      0        1
# 300   68       1   0       144   193    1        1      141      0        3
# 301   57       1   0       130   131    0        1      115      1        1
# 302   57       0   1       130   236    0        0      174      0        0
#
#      Slope  Ca  Thal  Result
# ...

# %%
select_int = df.select_dtypes(include=["int"]).columns

for col in select_int:
    df[col] = df[col].astype(float)

# %%
df
# Out:
#       Age  Gender   Cp  Trestbps   Chol  Fbs  Restecg  Thalach  Exang  \
# 0    63.0     1.0  3.0     145.0  233.0  1.0      0.0    150.0    0.0
# 1    37.0     1.0  2.0     130.0  250.0  0.0      1.0    187.0    0.0
# 2    41.0     0.0  1.0     130.0  204.0  0.0      0.0    172.0    0.0
# 3    56.0     1.0  1.0     120.0  236.0  0.0      1.0    178.0    0.0
# 4    57.0     0.0  0.0     120.0  354.0  0.0      1.0    163.0    1.0
# ..    ...     ...  ...       ...    ...  ...      ...      ...    ...
# 298  57.0     0.0  0.0     140.0  241.0  0.0      1.0    123.0    1.0
# 299  45.0     1.0  3.0     110.0  264.0  0.0      1.0    132.0    0.0
# 300  68.0     1.0  0.0     144.0  193.0  1.0      1.0    141.0    0.0
# 301  57.0     1.0  0.0     130.0  131.0  0.0      1.0    115.0    1.0
# 302  57.0     0.0  1.0     130.0  236.0  0.0      0.0    174.0    0.0
#
#      Oldpeak  Slope   Ca  Thal  Result
# 0        2.0    0.0  0.0   1.0     1.0
# 1        3.0    0.0  0.0   2.0     1.0
# ...

# %%
select_float = df.select_dtypes(include=["float"]).columns

for col in select_float:
    df[col] = df[col].astype(int)

# %%
df
# Out:
#      Age  Gender  Cp  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  \
# 0     63       1   3       145   233    1        0      150      0        2
# 1     37       1   2       130   250    0        1      187      0        3
# 2     41       0   1       130   204    0        0      172      0        1
# 3     56       1   1       120   236    0        1      178      0        0
# 4     57       0   0       120   354    0        1      163      1        0
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1        0
# 299   45       1   3       110   264    0        1      132      0        1
# 300   68       1   0       144   193    1        1      141      0        3
# 301   57       1   0       130   131    0        1      115      1        1
# 302   57       0   1       130   236    0        0      174      0        0
#
#      Slope  Ca  Thal  Result
# ...

# %%
df = df.astype(str)

# %%
df
# Out:
#     Age Gender Cp Trestbps Chol Fbs Restecg Thalach Exang Oldpeak Slope Ca  \
# 0    63      1  3      145  233   1       0     150     0       2     0  0
# 1    37      1  2      130  250   0       1     187     0       3     0  0
# 2    41      0  1      130  204   0       0     172     0       1     2  0
# 3    56      1  1      120  236   0       1     178     0       0     2  0
# 4    57      0  0      120  354   0       1     163     1       0     2  0
# ..   ..    ... ..      ...  ...  ..     ...     ...   ...     ...   ... ..
# 298  57      0  0      140  241   0       1     123     1       0     1  0
# 299  45      1  3      110  264   0       1     132     0       1     1  0
# 300  68      1  0      144  193   1       1     141     0       3     1  2
# 301  57      1  0      130  131   0       1     115     1       1     1  1
# 302  57      0  1      130  236   0       0     174     0       0     1  1
#
#     Thal Result
# 0      1      1
# 1      2      1
# ...

# %%
df = df.astype(float)

# %%
df
# Out:
#       Age  Gender   Cp  Trestbps   Chol  Fbs  Restecg  Thalach  Exang  \
# 0    63.0     1.0  3.0     145.0  233.0  1.0      0.0    150.0    0.0
# 1    37.0     1.0  2.0     130.0  250.0  0.0      1.0    187.0    0.0
# 2    41.0     0.0  1.0     130.0  204.0  0.0      0.0    172.0    0.0
# 3    56.0     1.0  1.0     120.0  236.0  0.0      1.0    178.0    0.0
# 4    57.0     0.0  0.0     120.0  354.0  0.0      1.0    163.0    1.0
# ..    ...     ...  ...       ...    ...  ...      ...      ...    ...
# 298  57.0     0.0  0.0     140.0  241.0  0.0      1.0    123.0    1.0
# 299  45.0     1.0  3.0     110.0  264.0  0.0      1.0    132.0    0.0
# 300  68.0     1.0  0.0     144.0  193.0  1.0      1.0    141.0    0.0
# 301  57.0     1.0  0.0     130.0  131.0  0.0      1.0    115.0    1.0
# 302  57.0     0.0  1.0     130.0  236.0  0.0      0.0    174.0    0.0
#
#      Oldpeak  Slope   Ca  Thal  Result
# 0        2.0    0.0  0.0   1.0     1.0
# 1        3.0    0.0  0.0   2.0     1.0
# ...

# %%
df = df.astype(int)
df
# Out:
#      Age  Gender  Cp  Trestbps  Chol  Fbs  Restecg  Thalach  Exang  Oldpeak  \
# 0     63       1   3       145   233    1        0      150      0        2
# 1     37       1   2       130   250    0        1      187      0        3
# 2     41       0   1       130   204    0        0      172      0        1
# 3     56       1   1       120   236    0        1      178      0        0
# 4     57       0   0       120   354    0        1      163      1        0
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1        0
# 299   45       1   3       110   264    0        1      132      0        1
# 300   68       1   0       144   193    1        1      141      0        3
# 301   57       1   0       130   131    0        1      115      1        1
# 302   57       0   1       130   236    0        0      174      0        0
#
#      Slope  Ca  Thal  Result
# ...

# %%
df.info()

# %%
df.columns

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.isna().sum()

# %%
df["City"]

# %%
df[["Name"]]

# %%
df["Age"].value_counts(dropna=True)

# %%
df["Age"].fillna('unknown',inplace=True)
df

# %%
age_mean = int(df["Age"].mean())
age_mean

# %%
df.mean()

# %%
Gender_median = int(df["Gender"].median())
Gender_median

# %%
df.median()

# %%
df=df.astype(float)
df

# %%
df=df.astype(int)
df

# %%
df["Age"] = df["Age"].astype(str)

# %%
df

# %%
df[["Gender"]]

# %%
df[["Trestbps"]]

# %%
select_cols = ["Age","Trestbps"]
for col in select_cols:
    df[col] = df[col].astype(str)

# %%
select_cols

# %%
import pandas as pd

data = {
    "CustomerId" : [101,102,103,104,105,106,107,108,109,110],
    "Name" : ["Sailu","Mahi","Yuvaraj","Prakash","Murali","Hari","Suresh","Rithu","Abhi","Padma"],
    "Age" : [25,30,35,28,40,32,27,45,38,29],
    "Gender" : ["Female","Male","Male","Male","Male","Male","Male","Female","Male","Female"],
    "Balance" : [50000,60000,45000,70000,30000,80000,55000,90000,65000,40000],
    "Salary" : [30000,45000,35000,50000,25000,60000,40000,75000,55000,32000],
    "Exited" : [0,1,0,0,1,0,1,0,0,1]
}

df = pd.DataFrame(data)

df
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 0         101    Sailu   25  Female    50000   30000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 3         104  Prakash   28    Male    70000   50000       0
# 4         105   Murali   40    Male    30000   25000       1
# 5         106     Hari   32    Male    80000   60000       0
# 6         107   Suresh   27    Male    55000   40000       1
# 7         108    Rithu   45  Female    90000   75000       0
# 8         109     Abhi   38    Male    65000   55000       0
# 9         110    Padma   29  Female    40000   32000       1

# %%
df=pd.read_csv("C:\\Users\\yuvra\\Downloads\\Bank_customer_churn.csv.crdownload")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df=pd.read_csv("C:\\Users\\yuvra\\Downloads\\Bank_customer_churn.csv.crdownload")
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 0         101    Sailu   25  Female    50000   30000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 3         104  Prakash   28    Male    70000   50000       0
# 4         105   Murali   40    Male    30000   25000       1

# %%
df.tail()
# Out:
#    CustomerId    Name  Age  Gender  Balance  Salary  Exited
# 5         106    Hari   32    Male    80000   60000       0
# 6         107  Suresh   27    Male    55000   40000       1
# 7         108   Rithu   45  Female    90000   75000       0
# 8         109    Abhi   38    Male    65000   55000       0
# 9         110   Padma   29  Female    40000   32000       1

# %%
df.isnull().sum()
# Out:
# CustomerId    0
# Name          0
# Age           0
# Gender        0
# Balance       0
# Salary        0
# Exited        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# CustomerId    0
# Name          0
# Age           0
# Gender        0
# Balance       0
# Salary        0
# Exited        0
# dtype: int64

# %%
df.describe()
# Out:
#        CustomerId        Age       Balance        Salary     Exited
# count    10.00000  10.000000     10.000000     10.000000  10.000000
# mean    105.50000  32.900000  58500.000000  44700.000000   0.400000
# std       3.02765   6.436873  18416.478129  15520.953579   0.516398
# min     101.00000  25.000000  30000.000000  25000.000000   0.000000
# 25%     103.25000  28.250000  46250.000000  32750.000000   0.000000
# 50%     105.50000  31.000000  57500.000000  42500.000000   0.000000
# 75%     107.75000  37.250000  68750.000000  53750.000000   1.000000
# max     110.00000  45.000000  90000.000000  75000.000000   1.000000

# %%
df["Balance"].value_counts()
# Out:
# Balance
# 50000    1
# 60000    1
# 45000    1
# 70000    1
# 30000    1
# 80000    1
# 55000    1
# 90000    1
# 65000    1
# 40000    1
# Name: count, dtype: int64

# %%
df.info()

# %%
df["Age"]=df["Age"].astype(int)

# %%
df["Age"]
# Out:
# 0    25
# 1    30
# 2    35
# 3    28
# 4    40
# 5    32
# 6    27
# 7    45
# 8    38
# 9    29
# Name: Age, dtype: int32

# %%
df=df.astype(int)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df=df.astype(int)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
# ...

# %%
df
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 0         101    Sailu   25  Female    50000   30000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 3         104  Prakash   28    Male    70000   50000       0
# 4         105   Murali   40    Male    30000   25000       1
# 5         106     Hari   32    Male    80000   60000       0
# 6         107   Suresh   27    Male    55000   40000       1
# 7         108    Rithu   45  Female    90000   75000       0
# 8         109     Abhi   38    Male    65000   55000       0
# 9         110    Padma   29  Female    40000   32000       1

# %%
df.columns
# Out:
# Index(['CustomerId', 'Name', 'Age', 'Gender', 'Balance', 'Salary', 'Exited'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# method 17 : drop_duplicates()

df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# method 23 : ffill
df['Age'].fillna(method = "ffill",inplace = True)
# Out:
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_10892\2206171685.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(method = "ffill",inplace = True)
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_10892\2206171685.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method = "ffill",inplace = True)

# %%
# method 24: bfill:
df['Age'].fillna(method = "bfill",inplace = True)
df
# Out:
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_10892\1648106835.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(method = "bfill",inplace = True)
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_10892\1648106835.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method = "bfill",inplace = True)
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# ...

# %%
# method 27 : replace() : replace value with another value

df.replace({'Gender': {'Male': '1', 'Female': '0'}},inplace = True)

# %%
df
# Out:
#    CustomerId     Name  Age Gender  Balance  Salary  Exited
# 0         101    Sailu   25      0    50000   30000       0
# 1         102     Mahi   30      1    60000   45000       1
# 2         103  Yuvaraj   35      1    45000   35000       0
# 3         104  Prakash   28      1    70000   50000       0
# 4         105   Murali   40      1    30000   25000       1
# 5         106     Hari   32      1    80000   60000       0
# 6         107   Suresh   27      1    55000   40000       1
# 7         108    Rithu   45      0    90000   75000       0
# 8         109     Abhi   38      1    65000   55000       0
# 9         110    Padma   29      0    40000   32000       1

# %%
# method 27 : replace() : replace value with another value

df.replace({'Gender': {'1': 'Male', '0': 'Female'}},inplace = True)

# %%
df
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 0         101    Sailu   25  Female    50000   30000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 3         104  Prakash   28    Male    70000   50000       0
# 4         105   Murali   40    Male    30000   25000       1
# 5         106     Hari   32    Male    80000   60000       0
# 6         107   Suresh   27    Male    55000   40000       1
# 7         108    Rithu   45  Female    90000   75000       0
# 8         109     Abhi   38    Male    65000   55000       0
# 9         110    Padma   29  Female    40000   32000       1

# %%
#  SORTING()

#method 28 : sort_values() --  sort the column values

df.sort_values('Age', ascending=False)
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 7         108    Rithu   45  Female    90000   75000       0
# 4         105   Murali   40    Male    30000   25000       1
# 8         109     Abhi   38    Male    65000   55000       0
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 5         106     Hari   32    Male    80000   60000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 9         110    Padma   29  Female    40000   32000       1
# 3         104  Prakash   28    Male    70000   50000       0
# 6         107   Suresh   27    Male    55000   40000       1
# 0         101    Sailu   25  Female    50000   30000       0

# %%
# method  29 : sort_index() sort the index
df.sort_index(ascending=True)
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 0         101    Sailu   25  Female    50000   30000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 3         104  Prakash   28    Male    70000   50000       0
# 4         105   Murali   40    Male    30000   25000       1
# 5         106     Hari   32    Male    80000   60000       0
# 6         107   Suresh   27    Male    55000   40000       1
# 7         108    Rithu   45  Female    90000   75000       0
# 8         109     Abhi   38    Male    65000   55000       0
# 9         110    Padma   29  Female    40000   32000       1

# %%
# method  29 : sort_index() sort the index
df.sort_index(ascending=True)
# Out:
#    CustomerId     Name  Age  Gender  Balance  Salary  Exited
# 0         101    Sailu   25  Female    50000   30000       0
# 1         102     Mahi   30    Male    60000   45000       1
# 2         103  Yuvaraj   35    Male    45000   35000       0
# 3         104  Prakash   28    Male    70000   50000       0
# 4         105   Murali   40    Male    30000   25000       1
# 5         106     Hari   32    Male    80000   60000       0
# 6         107   Suresh   27    Male    55000   40000       1
# 7         108    Rithu   45  Female    90000   75000       0
# 8         109     Abhi   38    Male    65000   55000       0
# 9         110    Padma   29  Female    40000   32000       1

# %%
# GROUPING & AGGREGATION
df.groupby("CustomerId")["Age"].mean()
# Out:
# CustomerId
# 101    25.0
# 102    30.0
# 103    35.0
# 104    28.0
# 105    40.0
# 106    32.0
# 107    27.0
# 108    45.0
# 109    38.0
# 110    29.0
# Name: Age, dtype: float64

# %%
df.groupby(["CustomerId","Gender"])['Age'].mean()
# Out:
# CustomerId  Gender
# 101         Female    25.0
# 102         Male      30.0
# 103         Male      35.0
# 104         Male      28.0
# 105         Male      40.0
# 106         Male      32.0
# 107         Male      27.0
# 108         Female    45.0
# 109         Male      38.0
# 110         Female    29.0
# Name: Age, dtype: float64

# %%
df["Age_Level"]= ["Older" if age > 45 else "Young" for age in  df['Age']]

# %%
df["Age_Level"]
# Out:
# 0    Young
# 1    Young
# 2    Young
# 3    Young
# 4    Young
# 5    Young
# 6    Young
# 7    Young
# 8    Young
# 9    Young
# Name: Age_Level, dtype: object

# %%
df["Age_Level"].value_counts()
# Out:
# Age_Level
# Young    10
# Name: count, dtype: int64

# %%
import pandas as pd
df = pd.DataFrame({'date': [ 
    '2024-01-15',      # YYYY-MM-DD 
    '15/01/2024',      # DD/MM/YYYY 
    '01-15-2024',      # MM-DD-YYYY 
    'Jan 15 2024',     # Month name 
    '15 January 2024', # Full month name 
    '20240115'         # Compact format 
]}) 
 
# Auto detect format 
df['date'] = pd.to_datetime(df['date'],format='mixed', dayfirst=True) 
df
# Out:
#         date
# 0 2024-01-15
# 1 2024-01-15
# 2 2024-01-15
# 3 2024-01-15
# 4 2024-01-15
# 5 2024-01-15

# %%
import pandas as pd

df = pd.DataFrame({'date': [
    '2024-01-15',
    '15/01/2024',
    '01-15-2024',
    'Jan 15 2024',
    '15 January 2024',
    '20240115'
]})

df['date'] = pd.to_datetime(df['date'], format='mixed', dayfirst=True)

df
# Out:
#         date
# 0 2024-01-15
# 1 2024-01-15
# 2 2024-01-15
# 3 2024-01-15
# 4 2024-01-15
# 5 2024-01-15
