# %%
sets={1, 2, 3, 2, 4, 1}

# %%
sets
# Out:
# {1, 2, 3, 4}

# %%
s={}
s
# Out:
# {}

# %%
sets={1, 2, 3, 2, 4, 1}
sets.add(6)
sets.add(10)
sets.add(50)
print(sets)
# Out:
# {1, 2, 3, 4, 6, 10, 50}

# %%
s = {10, 20, 30}
s.update([40, 50, 60])
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
s={10, 20, 30, 40, 50, 60}
s.remove(20)
s
# Out:
# {10, 30, 40, 50, 60}

# %%
s={10, 20, 30, 40, 50, 60}
s.discard(20)
s
# Out:
# {10, 30, 40, 50, 60}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.intersection(B)
# Out:
# {3, 4}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A.difference(B)
B.difference(A)
# Out:
# {5, 6}

# %%
s = {10, 20, 30, 40}
if s==25:
    print(25)
else:
    print(False)
# Out:
# False

# %%
set=[1, 2, 2, 3, 4, 4, 5]
print(len(set))
# Out:
# 7

# %% [markdown]
# for i in range(5):
#     num = int(input("Enter a number: "))

# %%
s={1,2,3,1,2,5}
print("Unique numbers", s)
# Out:
# Unique numbers {1, 2, 3, 5}

# %%
username = input("Enter username: ")
password = input("Enter password: ")
age = int(input("Enter age: "))
if username == "admin" and password == "python123" and age >= 18:
    print("Login Successful")

elif age < 18:
    print("You are too young to login")

else:
    print("Invalid Credentials")
# Out:
# Enter username:  sailu
# Enter password:  sailaja4@
# Enter age:  23
# Invalid Credentials

# %%
AI=float(input("Enter the marks: "))
Python=float(input("Enter the marks: "))
DL=float(input("Enter the marks: "))
java=float(input("Enter the marks: "))
ML=float(input("Enter the marks: "))
total = AI+Python+DL+java+ML
percentage = total/5
print("Percentage : ", percentage)
if percentage >= 90:
    print("Grade : A+")
elif percentage >= 80:
    print("Grade : A")
elif percentage >= 70:
    print("Grade : B")
elif percentage >= 60:
    print("Grade : c")
else:
    print("Fail")
if percentage >= 75:
    print("Passed with Distiction")
# Out:
# Enter the marks:  80
# Enter the marks:  90
# Enter the marks:  85
# Enter the marks:  70
# Enter the marks:  60
# Percentage :  77.0
# Grade : B
# Passed with Distiction

# %%
a=90
b=80
c=50
if a>=b and a>=c:
    print("Largest number: ",a)
elif b>=a and b>=c:
    print("Largest number: ",b)
else:
    print("Largest number: ",c)
# Out:
# Largest number:  90

# %%
a=49
if a%2==0 and a>=50:
    print("The number is even and greater than 50.")
else:
    print("The number does not satisfy the condition.")
# Out:
# The number does not satisfy the condition.

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter a year:  3000
# 3000 is not a Leap Year

# %%
year = 2000
if(year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("leap year", year)
else:
    print("Not a leap year", year)
# Out:
# leap year 2000

# %%
# check the no is positive,negitive,zero
num = int(input("Enter the value: "))
if num>0:
    print("Positive number: ",num)
elif num<0:
    print("Negative number: ",num)
else:
   print("Zero")
# Out:
# Enter the value:  4
# Positive number:  4

# %%
Age = int(input("Enter the Age: "))
if Age>=18 and num<18:
    print("Allow into the movie theater: ",Age)
else:
    print("Not Allow into the movie theater: ",Age)
# Out:
# Enter the Age:  23
# Allow into the movie theater:  23

# %%
num = int(input("Enter the value: "))
if num%2==0:
    print("number is divisible by 2: ",num)
else:
    print("not number is divisible by 2: ",num)
# Out:
# Enter the value:  4
# number is divisible by 2:  4

# %%
num1 = 500
num2 = 700
if num1>num2:
    print("Greater number is:",num1)
elif num2>num1:
    print("Greater number is:",num2)
else:
    print("Both are equal")
# Out:
# Greater number is: 700

# %%
ch = input("Enter the Character: ")
if ch.isupper():
    print("Given character is Uppercase",ch)
elif ch.islower():
    print("Given character is lowercase",ch)
else:
    print("Not a Alphabet")
# Out:
# Enter the Character:  Sailaja
# Not a Alphabet

# %%
time = int(input("Enter the Time: "))
if time < 12:
    print("Morning")
elif time >= 12 and time < 17:
    print("Afternoon") 
else:
    print("Evening")
# Out:
# Enter the Time:  6
# Morning

# %%
a=60
b=30
c=50
if(a>b):
    if(a>c):
        print("a is greatest num",a)
    else:
        print("c is greatest num",c)
else:
    if(b>c):
        print("b is greatest num",b)
    else:
        print("c is greatest num",c)
# Out:
# a is greatest num 60

# %%
Amt=int(input("Enter the Money: "))
pin=int(int(input("Enter the Money: "))
