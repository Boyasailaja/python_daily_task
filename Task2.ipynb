# %%
def greet():
    return f"Hello,Welcom to python!"

# %%
 greet()
# Out:
# 'Hello,Welcom to python!'

# %%
def show_date():
    print(datetime.datetime.now())

show_date()
# Out:
# 2026-07-17 18:53:10.032779

# %%
show_date()
# Out:
# 2026-07-17 18:53:18.340155

# %%
def square_root():
    for i in range(1,11):
        print(i," = ",i*i)

square_root()
# Out:
# 1  =  1
# 2  =  4
# 3  =  9
# 4  =  16
# 5  =  25
# 6  =  36
# 7  =  49
# 8  =  64
# 9  =  81
# 10  =  100

# %%
def line():
    print("-" * 50)

line()
# Out:
# --------------------------------------------------

# %%
def greet_user(name="Guest"):
    print("Hello", name)

greet_user()
greet_user("Sailu")
# Out:
# Hello Guest
# Hello Sailu

# %%
def power(base, exp=2):
    return base ** exp
power(2,3)
# Out:
# 8

# %%
def repeat_message(msg, times=3):
    for i in range(times):
        print(msg)
repeat_message("Welcome")
# Out:
# Welcome
# Welcome
# Welcome

# %%
def calculate_discount(price, discount=10):
    return price - (price * discount / 100)
calculate_discount(500)
# Out:
# 450.0

# %%
num=[1,2,3,4]
res=list(map(lambda x:"Even" if x%2==0 else "Odd",num))
res
# Out:
# ['Odd', 'Even', 'Odd', 'Even']
